# %%
import numpy as np
from collections import defaultdict
import pandas as pd
import treeswift as ts
import json
import re
import random
import string

# %%
N = 100

# %%
def compute_weighted_unifrac(tree_obj, true_labels, final_labels):
	true_abunds = {}
	final_abunds = {}

	u = 0
	D = 0
	for n in tree_obj.traverse_postorder():
		if n.is_root():
			break
		if n.is_leaf():
			true_abunds[n.label] = 0
			final_abunds[n.label] = 0
			if n.label in true_labels:
				true_abunds[n.label] = true_labels[n.label]
			if n.label in final_labels:
				final_abunds[n.label] = final_labels[n.label]	
		else:
			true_abunds[n.label] = 0
			final_abunds[n.label] = 0
			for c in n.child_nodes():
				true_abunds[n.label] += true_abunds[c.label]
				final_abunds[n.label] += final_abunds[c.label]
		u += n.edge_length * np.fabs(true_abunds[n.label] - final_abunds[n.label])
		D += n.edge_length * (true_abunds[n.label] + final_abunds[n.label])
	# print(u)
	return u/D

def compute_unifrac(tree_obj, true_labels, final_labels):
	true_abunds = {}
	final_abunds = {}

	u = 0
	D = 0
	for n in tree_obj.traverse_postorder():
		if n.is_root():
			break
		if n.is_leaf():
			true_abunds[n.label] = False
			final_abunds[n.label] = False
			if n.label in true_labels:
				true_abunds[n.label] = True
			if n.label in final_labels:
				final_abunds[n.label] = True
				
		else:
			true_abunds[n.label] = False
			final_abunds[n.label] = False
			for c in n.child_nodes():
				if true_abunds[c.label]:
					true_abunds[n.label] = True
				if final_abunds[c.label]:
					final_abunds[n.label] = True

		if true_abunds[n.label] and not final_abunds[n.label]:
			u += n.edge_length
		if not true_abunds[n.label] and final_abunds[n.label]:
			u += n.edge_length
		D += n.edge_length
	return u/D

def distance_between(u, v):
    """Return the distance between nodes ``u`` and ``v`` in this ``Tree``
    Args:
    ``u`` (``Node``): Node ``u``
    ``v`` (``Node``): Node ``v``
    Returns:
    ``float``: The distance between nodes ``u`` and ``v``
    """
    # print(u.get_label(), v.get_label())
    if u == v:
        return 0.0
    elif u == v.parent:
        return v.edge_length
    elif v == u.parent:
        return u.edge_length
    u_dists = {u: 0.0}
    v_dists = {v: 0.0}
    c = u
    p = u.parent  # u traversal
    while p is not None:
        u_dists[p] = u_dists[c]
        if c.edge_length is not None:
            u_dists[p] += c.edge_length
        c = p
        p = p.parent
    if v in u_dists:
        return u_dists[v]
    c = v
    p = v.parent  # v traversal
    while p is not None:
        v_dists[p] = v_dists[c]
        if c.edge_length is not None:
            v_dists[p] += c.edge_length
        if p in u_dists:
            return u_dists[p] + v_dists[p]
        c = p
        p = p.parent

# %%
df_16S = pd.read_csv("./data_16S.tsv", sep="\t", index_col="id")
df_16S = df_16S.div(df_16S.sum(axis=1), axis=0)
df_16S.head()
# Out:
#        1b158b8b2922d4fcad5d9cea607cbb7d  c1dc9ad5116d96b8ed863458fc0d0aec  \
# id
# 50076                          0.845600                          0.059918
# 510                            0.001760                          0.233586
# 80129                          0.029748                          0.043962
# 50395                          0.106462                          0.178344
# 156                            0.448909                          0.108317
#
#        6a6fcf8f9b8bb1ab9e5f8456ee7fb109  aed3f59201e3b9d21858f36557f42a80  \
# id
# 50076                          0.026361                          0.010328
# 510                            0.005046                          0.000000
# 80129                          0.011572                          0.026226
# 50395                          0.000666                          0.000848
# 156                            0.151102                          0.009508
#
#        f95cab37fba4160de15015f4d520839f  cda4e6f933bb3108ea3e92f9db411c00  \
# id
# 50076                          0.006898                          0.004773
# 510                            0.000000                          0.000117
# 80129                          0.000000                          0.000000
# 50395                          0.016230                          0.000182
# 156                            0.001329                          0.001431
#
#        afd87e82de329a1ed75b98b5b606843c  668fdb718997fc1589c7817655d4bb5f  \
# id
# 50076                          0.004027                          0.003729
# 510                            0.000235                          0.000645
# 80129                          0.012956                          0.000566
# 50395                          0.016290                          0.002120
# 156                            0.000358                          0.000000
#
#        51e441cbdcc80da0656e82293ae160b5  ee293984c0110b2eeceb8427fdf448fb  \
# id
# 50076                          0.003207                          0.002498
# 510                            0.000235                          0.003051
# 80129                          0.000000                          0.005912
# 50395                          0.000606                          0.047236
# 156                            0.000000                          0.001789
#
#        ...  13a37c86712739ee091c0fbc2a13e1cb  \
# id     ...
# 50076  ...                               0.0
# 510    ...                               0.0
# 80129  ...                               0.0
# 50395  ...                               0.0
# 156    ...                               0.0
#
#        d94a05561f7643eeb4a75f59435df2df  6b1597644d7942d2276e0facc93bc63b  \
# id
# 50076                               0.0                               0.0
# 510                                 0.0                               0.0
# 80129                               0.0                               0.0
# 50395                               0.0                               0.0
# 156                                 0.0                               0.0
#
#        ac0f7d14d0cc7d87687a7a72172dba00  e803ff46adaa0fa149ef151b082378a0  \
# id
# 50076                               0.0                               0.0
# 510                                 0.0                               0.0
# 80129                               0.0                               0.0
# 50395                               0.0                               0.0
# 156                                 0.0                               0.0
#
#        a11e3437a79a85d83c4bcdd1acd6ff27  c6adabe4621cc8ab924f25db04dec07c  \
# id
# 50076                               0.0                               0.0
# 510                                 0.0                               0.0
# 80129                               0.0                               0.0
# 50395                               0.0                               0.0
# 156                                 0.0                               0.0
#
#        e8120a2c1c4a6888ab33d17a033a6a56  7c02b294ddbf1c8eb03ac162df74780e  \
# id
# 50076                               0.0                               0.0
# 510                                 0.0                               0.0
# 80129                               0.0                               0.0
# 50395                               0.0                               0.0
# 156                                 0.0                               0.0
#
#        e48e37a0467ce3d2ff2c3a0f1167497b
# id
# 50076                               0.0
# 510                                 0.0
# 80129                               0.0
# 50395                               0.0
# 156                                 0.0
#
# [5 rows x 480 columns]

# %%
df_metadata = pd.read_csv("./metadata.tsv", sep="\t")
df_metadata.head()
# Out:
#    #SampleID sample group
# 0          3     S3    TD
# 1         10    S10    TD
# 2         45    S45    TD
# 3         76    S76    TD
# 4         78    S78    TD

# %%
with open("./depp_placements.jplace", 'r') as f:
    jplace = json.load(f)

# %%
tree_wp = ts.read_tree_newick(re.sub(r'{[0-9]+}', '', jplace["tree"]))
ic = 0
for node in tree_wp.traverse_postorder(leaves=True, internal=True):
    # if node.get_label() == None or not(node.get_label().startswith("G")):
    node.set_label(f"N{ic}")
    ic+=1
tree_wp.write_tree_newick("./tree_backbone.nwk")

label_to_node = tree_wp.label_to_node(selection='all')

for placement in jplace["placements"]:
    edge_num, likelihood, like_weight_ratio, distal_length, pendant_length = placement["p"][0]
    child = label_to_node[f"N{edge_num}"]
    # distal_length = child.get_edge_length() - distal_length
    if (distal_length > child.get_edge_length()):
        while (distal_length > child.get_edge_length()):
            distal_length -=  child.get_edge_length()
            child = child.get_parent()
    parent = child.get_parent()
    placed = ts.Node(label=placement["n"][0], edge_length=pendant_length)
    inner = ts.Node(label=placement["n"][0]+"i", edge_length=distal_length)
    placed.set_parent(inner)
    inner.set_parent(parent)
    parent.remove_child(child)
    parent.add_child(inner)
    inner.add_child(child)
    inner.add_child(placed)
    child.set_parent(inner)
    child.set_edge_length(child.get_edge_length() - distal_length)

# %%
tree_wp.write_tree_newick("./tree_wplacements.nwk")

# %%
wunifrac_pairs = defaultdict(dict)
unifrac_pairs = defaultdict(dict)
for index1, row1 in df_16S.iterrows():
    for index2, row2 in df_16S.iterrows():
        wunifrac = compute_weighted_unifrac(tree_wp, row2.to_dict(), row1.to_dict())
        unifrac = compute_unifrac(tree_wp, row2[row2!=0].to_dict(), row1[row1!=0].to_dict())
        wunifrac_pairs[index1][index2] = wunifrac
        unifrac_pairs[index1][index2] = unifrac

# %%
df_wunifrac = pd.DataFrame(wunifrac_pairs)
df_unifrac = pd.DataFrame(unifrac_pairs)

# %%
df_wunifrac.to_csv("./distance_matrix-wunifrac-depp_only.tsv", sep="\t")
df_unifrac.to_csv("./distance_matrix-unifrac-depp_only.tsv", sep="\t")

# %%
label_to_node = tree_wp.label_to_node(selection='leaves')
reference_distances = defaultdict(dict)
backbone_references = [val for key, val in label_to_node.items() if key.startswith("N")]
for placed in df_16S.columns:
    reference_distances[placed] = dict(list(map(lambda x: (x, distance_between(label_to_node[placed], x)), backbone_references)))
# Out:
# 1b158b8b2922d4fcad5d9cea607cbb7d
# c1dc9ad5116d96b8ed863458fc0d0aec
# 6a6fcf8f9b8bb1ab9e5f8456ee7fb109
# aed3f59201e3b9d21858f36557f42a80
# f95cab37fba4160de15015f4d520839f
# cda4e6f933bb3108ea3e92f9db411c00
# afd87e82de329a1ed75b98b5b606843c
# 668fdb718997fc1589c7817655d4bb5f
# 51e441cbdcc80da0656e82293ae160b5
# ee293984c0110b2eeceb8427fdf448fb
# 73bf8d1a5983e34a0cb84e3cae127815
# dc2721103659fe9f1d3ead56a11df243
# 90a05d597112b554e4480a8eaae4e0aa
# cc2d96099f530b503371e5ddca8c0a58
# 45a68a9eee3cf83e27f4ea309d57ffc3
# a5189f77a2cfeab3bc1602ff5c8ac3e9
# e553b9a0bb32467c71c89a4e97e55792
# b20c095fd654b84cebdbfe4faa0a1409
# 8114b1d0274e9e4bb6c91f6af1b8fac8
# 8347bd34436f72573fcde614b95d4702
# 6797371940252066205fbd1b85d623ce
# 2d79a0f0dfbccfd07a0509a4623bb1db
# 99c40a5312fad44f7ab6022d13d53441
# 5898ec3a80ad76122c711774a3be2994
# 01b812d1959391432c283754cebad70b
# 7011e4bed602e69b44398e53b20bce42
# 2c28f59ac40a4baed8a1ab2d6bd7f35e
# 8a3a7b91dcf3ddcf651fe327d2693100
# 906a67a5dd02732c0a80dceafc4d69b8
# d3853d2182c91bc13e3fe91b590b9111
# 13a37c86712739ee091c0fbc2a13e1cb
# d94a05561f7643eeb4a75f59435df2df
# 6b1597644d7942d2276e0facc93bc63b
# ac0f7d14d0cc7d87687a7a72172dba00
# e803ff46adaa0fa149ef151b082378a0
# a11e3437a79a85d83c4bcdd1acd6ff27
# c6adabe4621cc8ab924f25db04dec07c
# e8120a2c1c4a6888ab33d17a033a6a56
# 7c02b294ddbf1c8eb03ac162df74780e
# e48e37a0467ce3d2ff2c3a0f1167497b

# %%
mixture_distances = defaultdict(lambda: defaultdict(float))
for sample, row in df_16S.iterrows():
    for key_placed, p in row.to_dict().items():
        for key_ref, d in reference_distances[key_placed].items():
            mixture_distances[sample][key_ref] += p*d

# %%
df_mixture = pd.DataFrame(mixture_distances)
df_mixture.to_csv("mixture_distances-all_references.tsv", sep="\t")

# %%
df_mixture
# Out:
#              50076       510         80129       50395       156    \
# N21068   96.502870  336.010219  350.427550  303.908019  213.333701
# N21067   96.178202  335.685552  350.102883  303.583352  213.009034
# N21074   98.210906  337.718255  352.135587  305.617005  215.107856
# N21073   99.504073  339.011423  353.428754  306.910172  216.401024
# N21071   98.675705  338.183054  352.600386  306.081804  215.572655
# ...            ...         ...         ...         ...         ...
# N7      297.976775  309.828634  332.550980  308.382640  310.957318
# N4      289.673991  301.676268  324.248196  300.263617  302.654534
# N3      272.375244  284.377522  306.949449  282.964871  285.355787
# N1      282.406780  294.409058  316.980986  292.996407  295.387324
# N0      270.123584  282.125862  304.697789  280.713211  283.104127
#
#              160         3           6165        715         147    ...  \
# N21068   85.257667  338.930950  259.119766  324.670969  332.434543  ...
# N21067   84.932999  338.606283  258.795099  324.346302  332.109876  ...
# N21074   86.965703  340.638987  260.827803  326.407594  334.142580  ...
# N21073   88.258871  341.932154  262.120970  327.700761  335.435747  ...
# N21071   87.430502  341.103785  261.292601  326.872392  334.607378  ...
# ...            ...         ...         ...         ...         ...  ...
# N7      296.763251  313.968889  313.412006  305.446488  310.697203  ...
# N4      288.460467  305.680967  305.109221  297.143703  302.394418  ...
# N3      271.161720  288.382220  287.810475  279.844957  285.095672  ...
# N1      281.193256  298.413757  297.842011  289.876493  295.127208  ...
# N0      268.910060  286.130560  285.558815  277.593297  282.844012  ...
#
#              521         6128        538         6168        6163   \
# N21068  342.635584  333.227279  352.022886  293.061487   81.295086
# N21067  342.310916  332.902612  351.698219  292.736819   80.970419
# N21074  344.343620  334.935315  353.730923  294.769523   83.003122
# N21073  345.636787  336.228483  355.024090  296.062690   84.296290
# N21071  344.808419  335.400114  354.195722  295.234322   83.467921
# ...            ...         ...         ...         ...         ...
# N7      321.483633  307.278925  333.477833  310.610955  297.567465
# N4      313.180848  298.976140  325.175048  302.308171  289.264680
# N3      295.882102  281.677394  307.876302  285.009424  271.965934
# N1      305.913638  291.708930  317.907838  295.040961  281.997470
# N0      293.630442  279.425733  305.624642  282.757764  269.714274
#
#              540         76          78          125         101
# N21068  333.122791  184.544546  275.143112  333.352485  329.557770
# N21067  332.798124  184.219879  274.818445  333.027818  329.233103
# N21074  334.830828  187.846336  277.093149  335.078684  331.292677
# N21073  336.123995  189.139503  278.386316  336.371852  332.585844
# N21071  335.295627  188.311134  277.557948  335.543483  331.757476
# ...            ...         ...         ...         ...         ...
# N7      311.161191  314.434073  304.797513  308.842986  307.703859
# N4      302.858406  306.131288  296.494729  300.540201  299.401075
# N3      285.559660  288.832542  279.195982  283.241455  282.102328
# N1      295.591196  298.864078  289.227518  293.272991  292.133864
# N0      283.308000  286.580881  276.944322  280.989795  279.850668
#
# [10575 rows x 29 columns]

# %%
with open("clusters-max300.txt", 'r') as f:
    cluster_map = dict(list(map(lambda line: line.strip().split(), f.readlines()[1: ])))

# %%
clusters = list(set(cluster_map.values()))
label_to_node = tree_wp.label_to_node(selection='all')
clade_portions = defaultdict(dict)

# %%
for c in clusters:
    clade = ts.read_tree_newick(f"extracted_clades/clade_{c}.nwk")
    root = ts.Node(label="root", edge_length=0)
    root.add_child(clade.root)
    clade.root.set_parent(root)
    label_to_cnode = clade.label_to_node(selection='all')

    for placement in jplace["placements"]:
        edge_num, likelihood, like_weight_ratio, distal_length, pendant_length = placement["p"][0]
        child = label_to_cnode.get(f"N{edge_num}", None)
        if child == None:
            continue
        if (distal_length > child.get_edge_length()):
            while (distal_length > child.get_edge_length()):
                distal_length -=  child.get_edge_length()
                child = child.get_parent()
        parent = child.get_parent()
        placed = ts.Node(label=placement["n"][0], edge_length=pendant_length)
        inner = ts.Node(label=placement["n"][0]+"i", edge_length=distal_length)
        placed.set_parent(inner)
        inner.set_parent(parent)
        parent.remove_child(child)
        parent.add_child(inner)
        inner.add_child(child)
        inner.add_child(placed)
        child.set_parent(inner)
        child.set_edge_length(child.get_edge_length() - distal_length)
    
    label_to_cnode = clade.label_to_node(selection='leaves')

    df_16S_sub = df_16S[[key for key, val in label_to_cnode.items() if not(key.startswith("N"))]]
    for sample, total_p in df_16S_sub.sum(axis=1).to_dict().items():
        clade_portions[sample][c] = total_p
    
    df_16S_sub = df_16S_sub.div((df_16S_sub).sum(axis=1), axis=0)

    reference_distances = defaultdict(dict)
    backbone_references = [val for key, val in label_to_cnode.items() if key.startswith("N")]
    for placed in df_16S_sub.columns:
        reference_distances[placed] = dict(list(map(lambda x: (x, distance_between(label_to_cnode[placed], x)), backbone_references)))

    mixture_distances = defaultdict(lambda: defaultdict(float))
    for sample, row in df_16S_sub.iterrows():
        for key_placed, p in row.to_dict().items():
            for key_ref, d in reference_distances[key_placed].items():
                mixture_distances[sample][key_ref] += p*d
    df_mixture = pd.DataFrame(mixture_distances)
    df_mixture = df_mixture.dropna(axis=1, how="all")
    for sample in df_mixture.columns:
        df_mixture[sample].to_csv(f"mixture_distances-per_sample/mixture_distances-sample_{sample}-clade_{c}.tsv", sep="\t", header=None)

# %%
tree_wp_all = ts.read_tree_newick("tree_backbone.nwk")
# tree_wp_all.scale_edges(0.01)
label_to_node = tree_wp_all.label_to_node(selection='all')
samples_to_p = defaultdict(dict)

for sample, p_total_map in clade_portions.items():
    for c, p_total_c in p_total_map.items():
        if p_total_c == 0:
            continue
        # print(sample, c, p_total_c)
        pp_details_path = f"decodiphy_placements/placements-sample_{sample}-clade_{c}/all_rounds.json"
        tree_pp_path = f"decodiphy_placements/placements-sample_{sample}-clade_{c}/pruned_tree.trees"
        clade_path = f"extracted_clades/clade_{c}.nwk"
        try:
            with open(pp_details_path, 'r') as f:
                pp_details = json.load(f)
        except FileNotFoundError:
            continue
        tree_pp = ts.read_tree_newick(tree_pp_path)
        clade =  ts.read_tree_newick(clade_path)
        true_labels = [nd.get_label() for nd in clade.traverse_postorder()]
        name_mapping = {}
        for ix, nd in enumerate(tree_pp.traverse_postorder()):
            name_mapping[nd.get_label()] = true_labels[ix]
            nd.set_label(true_labels[ix])
        
        pp_final = pp_details[-1]
        k = pp_final['k']
        pv = pp_final['p']
        xv = pp_final['x']
        anchors = [name_mapping[str(a)] for a in pp_final['anchors']]
        pendant_length = pp_final['y'] * 100
        for a, x, p in zip(anchors, xv, pv):
            child = label_to_node.get(a, None)
            if child == None:
                continue
            distal_length = child.get_edge_length() * (1-x)
            name = ''.join(random.choices(string.ascii_uppercase + string.digits, k=N))
            samples_to_p[sample][name] = abs(p*p_total_c)
            if (distal_length > child.get_edge_length()):
                while (distal_length > child.get_edge_length()):
                    distal_length -=  child.get_edge_length()
                    child = child.get_parent()
            parent = child.get_parent()
            placed = ts.Node(label=name, edge_length=0)
            inner = ts.Node(label=name+"i", edge_length=distal_length)
            placed.set_parent(inner)
            inner.set_parent(parent)
            parent.remove_child(child)
            parent.add_child(inner)
            inner.add_child(child)
            inner.add_child(placed)
            child.set_parent(inner)
            child.set_edge_length(child.get_edge_length() - distal_length)

# %%
wunifrac_pairs = defaultdict(dict)
unifrac_pairs = defaultdict(dict)
for sample1, p1 in samples_to_p.items():
    for sample2, p2 in samples_to_p.items():
        wunifrac_pairs[sample1][sample2] = compute_weighted_unifrac(tree_wp_all, p1, p2)
        unifrac_pairs[sample1][sample2] = compute_unifrac(tree_wp_all, p1, p2)

# %%
df_wunifrac = pd.DataFrame(wunifrac_pairs)
df_unifrac = pd.DataFrame(unifrac_pairs)

# %%
df_wunifrac.to_csv("./distance_matrix-wunifrac-depp_w_decodiphy.tsv", sep="\t")
df_unifrac.to_csv("./distance_matrix-unifrac-depp_w_decodiphy.tsv", sep="\t")
